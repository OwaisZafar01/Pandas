# %% [markdown]
# # Complete Pandas

# %% [markdown]
# ## Pandas DataFrame

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### DataFrame Creation

# %%
# Using Lists
data = [['Owais','Zafar','Samina'],
        [21,49,47],
        ['M','M','F']]

df = pd.DataFrame(data, columns=['Name','Age','Gender'])
print(df)
# Out:
#     Name    Age  Gender
# 0  Owais  Zafar  Samina
# 1     21     49      47
# 2      M      M       F

# %%
# using Dict

data = {
    'Name':['Owais','Huzaifa','Zafar','Samina','david','Albert','King'],
    'IQ': [90,100,85,75,40,0,0],
    'marks':[80,80,20,90,95,0,0],
    'package':[2,12,14,10,1,0,0]
}
df = pd.DataFrame(data)
df.set_index('Name', inplace=True)
print(df)
# Out:
#           IQ  marks  package
# Name
# Owais     90     80        2
# Huzaifa  100     80       12
# Zafar     85     20       14
# Samina    75     90       10
# david     40     95        1
# Albert     0      0        0
# King       0      0        0

# %%
data = [
    {'Name':'Owais','Age':25,'Gnder': 'M'},
    {'Name':'Zafar','Age':48,'Gnder': 'M'}
]
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age Gnder
# 0  Owais   25     M
# 1  Zafar   48     M

# %%
# Using read_csv

df1 = pd.read_csv('movies.csv')
df1
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
df2 = pd.read_csv('ipl-matches.csv')
df2
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# ## DataFrame Attributes and Methods

# %%
# df1 me pehla dataset store hai jo ke hai movies wala 
# df2 me dosra dataset store hai jo ke hai ipl matches wala 

# shape

shape = df1.shape
print(shape)
shape = df2.shape
print(shape)
# Out:
# (1629, 18)
# (950, 20)

# %%
# dtypes

typ = df1.dtypes
print(typ)
print('\n')
typ = df2.dtypes
print(typ)
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object
#
#
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# ...

# %%
# index
idx = df1.index
print(idx)

idx = df2.index
print(idx)
# Out:
# RangeIndex(start=0, stop=1629, step=1)
# RangeIndex(start=0, stop=950, step=1)

# %%
# columns
col = df1.columns.tolist()
print(col)
# Out:
# ['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y', 'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres', 'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors', 'wins_nominations', 'release_date']

# %%
# values

val = df.values
print(val)
# Out:
# [['Owais' 25 'M']
#  ['Zafar' 48 'M']]

# %%
# head  

h = df1.head(3)
h
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
# ...

# %%
# tail

t = df2.tail(3)
t
# Out:
#          ID        City        Date   Season MatchNumber  \
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                  Team2  \
# 947             Delhi Daredevils       Rajasthan Royals
# 948              Kings XI Punjab    Chennai Super Kings
# 949  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver            WinningTeam    WonBy  Margin method  \
# 947          bat         N       Delhi Daredevils  Wickets     9.0    NaN
# ...

# %%
# sample

s = df1.sample(2)
s
# Out:
#         title_x    imdb_id                                        poster_path  \
# 1016  Rock On!!  tt1230165  https://upload.wikimedia.org/wikipedia/en/thum...
# 599       Gippi  tt2814372  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link    title_y  \
# 1016  https://en.wikipedia.org/wiki/Rock_On!!_(2008_...  Rock On!!
# 599                 https://en.wikipedia.org/wiki/Gippi      Gippi
#
#      original_title  is_adult  year_of_release runtime        genres  \
# 1016      Rock On!!         0             2008     145   Drama|Music
# 599           Gippi         0             2013      95  Comedy|Drama
#
#       imdb_rating  imdb_votes  \
# 1016          7.8       19565
# 599           5.6         734
#
#                                                   story  \
# 1016  Sakshi Shroff  the lonely and neglected wife o...
# 599   Gippi is a 14-year-old girl who lives in Simla...
#
# ...

# %%
# info
info = df2.info()
print(info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# describe

desc = df1.describe()
print(desc)
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
# isnull

null = df1.isnull().sum()
null
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
# duplicated
dup = df.duplicated().sum()
print(dup)
dup = df.duplicated()
dup
# Out:
# 1
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
# rename

print(df)

df.rename(columns={'marks':'percentage', 'package':'Lpa'}, inplace=True)
print(df)
# Out:
#           IQ  percentage  Lpa
# Name
# Owais     90          80    2
# Huzaifa  100          80   12
# Zafar     85          20   14
# Samina    75          90   10
# david     40          95    1
# Albert     0           0    0
# King       0           0    0
#           IQ  percentage  Lpa
# Name
# Owais     90          80    2
# Huzaifa  100          80   12
# Zafar     85          20   14
# Samina    75          90   10
# david     40          95    1
# Albert     0           0    0
# King       0           0    0

# %% [markdown]
# ## Maths Method

# %%
# sum/ mean/ median/ mode/min/ max/ std/ var/
print(df)
print(df.sum(axis=0))
print(df.sum(axis=1))
# Out:
#     IQ  percentage  Lpa
# 0   90          80    2
# 1  100          80   12
# 2   85          20   14
# 3   75          90   10
# 4   40          95    1
# 5    0           0    0
# 6    0           0    0
# IQ            390
# percentage    365
# Lpa            39
# dtype: int64
# 0    172
# 1    192
# 2    119
# 3    175
# 4    136
# 5      0
# 6      0
# dtype: int64

# %% [markdown]
# ## Selecting Columns from a DataFrame

# %%
# fetching cols
print(df)
print('\n')
print(df['percentage'])
# Out:
#     IQ  percentage  Lpa
# 0   90          80    2
# 1  100          80   12
# 2   85          20   14
# 3   75          90   10
# 4   40          95    1
# 5    0           0    0
# 6    0           0    0
#
#
# 0    80
# 1    80
# 2    20
# 3    90
# 4    95
# 5     0
# 6     0
# Name: percentage, dtype: int64

# %%
print(df[['IQ','percentage']])
# Out:
#     IQ  percentage
# 0   90          80
# 1  100          80
# 2   85          20
# 3   75          90
# 4   40          95
# 5    0           0
# 6    0           0

# %% [markdown]
# ## Selecting rows From a DataFrame

# %%
# iloc searching using index positions
# loc searching using index labels

# loc aur iloc [row, column]

# iloc
print(df)
print('\n')
print(df.iloc[0])
print(df.iloc[0:3])
df.iloc[[0,1]]
# Out:
#           IQ  marks  package
# Name
# Owais     90     80        2
# Huzaifa  100     80       12
# Zafar     85     20       14
# Samina    75     90       10
# david     40     95        1
# Albert     0      0        0
# King       0      0        0
#
#
# IQ         90
# marks      80
# package     2
# Name: Owais, dtype: int64
# Name
# Owais      80
# Huzaifa    80
# Zafar      20
# Name: marks, dtype: int64
#           IQ  marks  package
# Name
# Owais     90     80        2
# Huzaifa  100     80       12

# %%
# loc

print(df)
df.loc[['Owais','david']]
print('\n')

print('\n')
print(df.loc['Owais'])
print('\n')
print(df.loc['Owais':'King', 'marks'])

df.loc[['Owais','david']]
# Out:
#           IQ  marks  package
# Name
# Owais     90     80        2
# Huzaifa  100     80       12
# Zafar     85     20       14
# Samina    75     90       10
# david     40     95        1
# Albert     0      0        0
# King       0      0        0
#
#
#
#
# IQ         90
# marks      80
# package     2
# Name: Owais, dtype: int64
#
#
# Name
# Owais      80
# Huzaifa    80
# Zafar      20
# Samina     90
# david      95
# Albert      0
# King        0
# Name: marks, dtype: int64
#        IQ  marks  package
# Name
# Owais  90     80        2
# david  40     95        1

# %% [markdown]
# ## Selecting both rows and columns from a DataFrame

# %%
df1.iloc[0:3, 0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# ## Filtering a DataFrame

# %%
df2.head(3)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# ...

# %%
# find all the final winners

#mask = df2['MatchNumber'] == 'Final'
#new_df = df2[mask]
#new_df[['Season','WinningTeam']]

df2[df2['MatchNumber'] == 'Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# how many super overs occured

a = df2['SuperOver'].value_counts()['Y']
print(a)

a = df2[df2['SuperOver'] == 'Y']['SuperOver'].count()
print(a)
# Out:
# 14
# 14

# %%
# how many matches has csk won in kolkata

len(df2[(df2['WinningTeam'] == 'Chennai Super Kings') & (df2['City']=='Kolkata')])
# Out:
# 5

# %%
# toss winner is a match winner in %

(df2[df2['TossWinner'] == df2['WinningTeam']].shape[0]/df2.shape[0])* 100
# Out:
# 51.473684210526315

# %%
df1.head(3)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
# ...

# %%
# movies with rating higher than 8 and votes > 10000

print(df1[(df1['imdb_rating']>8) & (df1['imdb_votes']>10000)]['title_x'].values.tolist())
len(df1[(df1['imdb_rating']>8) & (df1['imdb_votes']>10000)]['title_x'].values.tolist())
# Out:
# ['Uri: The Surgical Strike', 'Gully Boy', 'Article 15 (film)', 'Super 30 (film)', 'Tumbbad', 'Andhadhun', 'Pink (2016 film)', 'Dangal (film)', 'Masaan', 'Drishyam (2015 film)', 'Talvar (film)', 'Queen (2014 film)', 'Haider (film)', 'Ugly (film)', 'PK (film)', 'Vishwaroopam', 'Bhaag Milkha Bhaag', 'Shahid (film)', 'Paan Singh Tomar (film)', 'Kahaani', 'Gangs of Wasseypur', 'Gangs of Wasseypur – Part 2', 'Barfi!', 'OMG – Oh My God!', 'Zindagi Na Milegi Dobara', 'Udaan (2010 film)', '3 Idiots', 'Gulaal (film)', 'Black Friday (2007 film)', 'Chak De! India', 'Taare Zameen Par', 'Khosla Ka Ghosla', 'Lage Raho Munna Bhai', 'Omkara (2006 film)', 'Rang De Basanti', 'Black (2005 film)', 'Iqbal (film)', 'Swades', 'Munna Bhai M.B.B.S.', 'The Legend of Bhagat Singh', 'Lagaan', 'Lagaan', 'Dil Chahta Hai']
# 43

# %%
# action movies with rating higher than 7.5
df1[(df1['genres'].str.split('|').apply(lambda x:'Action' in x)) & (df1['imdb_rating']>7.5)].head(5)
df1[(df1['genres'].str.contains('Action')) & (df1['imdb_rating']>7.5)].head(5)
# Out:
#                            title_x    imdb_id  \
# 0         Uri: The Surgical Strike  tt8291224
# 41            Family of Thakurganj  tt8897986
# 84                       Mukkabaaz  tt7180544
# 106                          Raazi  tt7098658
# 110  Parmanu: The Story of Pokhran  tt6826438
#
#                                            poster_path  \
# 0    https://upload.wikimedia.org/wikipedia/en/thum...
# 41   https://upload.wikimedia.org/wikipedia/en/9/99...
# 84   https://upload.wikimedia.org/wikipedia/en/thum...
# 106  https://upload.wikimedia.org/wikipedia/en/thum...
# 110  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                              wiki_link  \
# 0    https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 41   https://en.wikipedia.org/wiki/Family_of_Thakur...
# 84             https://en.wikipedia.org/wiki/Mukkabaaz
# 106                https://en.wikipedia.org/wiki/Raazi
# 110  https://en.wikipedia.org/wiki/Parmanu:_The_Sto...
#
# ...

# %% [markdown]
# ## Adding New Columns

# %%
df['Country'] = 'Pakistan'

# %%
df1.dropna(inplace=True)
df1['Lead Actor']= df1['actors'].str.split('|').apply(lambda x:x[0])
df1.head(3)
# Out:
#               title_x     imdb_id  \
# 11          Gully Boy   tt2395469
# 34      Yeh Hai India   tt5525846
# 37  Article 15 (film)  tt10324144
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
# 37  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link        title_y  \
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# 34      https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India
# 37  https://en.wikipedia.org/wiki/Article_15_(film)     Article 15
#
#    original_title  is_adult  year_of_release runtime                  genres  \
# 11      Gully Boy         0             2019     153             Drama|Music
# 34  Yeh Hai India         0             2017     128  Action|Adventure|Drama
# 37     Article 15         0             2019     130             Crime|Drama
#
# ...

# %%
df['Grade'] = 'F'
df.loc[df['percentage']>= 90, 'Grade'] = 'A+'
df.loc[ (df['percentage']>= 80) & (df['percentage']< 90), 'Grade'] = 'A'
df
# Out:
#           IQ  percentage  Lpa   Country Grade
# Name
# Owais     90          80    2  Pakistan     A
# Huzaifa  100          80   12  Pakistan     A
# Zafar     85          20   14  Pakistan     F
# Samina    75          90   10  Pakistan    A+
# david     40          95    1  Pakistan    A+
# Albert     0           0    0  Pakistan     F
# King       0           0    0  Pakistan     F

# %% [markdown]
# ## Imp DataFrame Methods

# %%
# astype
df['percentage'] = df['percentage'].astype('float32')
df
# Out:
#           IQ  percentage  Lpa   Country Grade
# Name
# Owais     90        80.0    2  Pakistan     A
# Huzaifa  100        80.0   12  Pakistan     A
# Zafar     85        20.0   14  Pakistan     F
# Samina    75        90.0   10  Pakistan    A+
# david     40        95.0    1  Pakistan    A+
# Albert     0         0.0    0  Pakistan     F
# King       0         0.0    0  Pakistan     F

# %%
# value_counts 
df
df.value_counts()
# Out:
# Name  Age   City       Country
# Ali   25.0  Lahore     Pakistan    1
# Zara  22.0  Islamabad  Pakistan    1
# Name: count, dtype: int64

# %%
df2.head(3)
# find which player has won most potm in final ans qualifiers

df2[~df2['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# KA Pollard           3
# F du Plessis         3
# SK Raina             3
# A Kumble             2
# MK Pandey            2
# YK Pathan            2
# M Vijay              2
# JJ Bumrah            2
# AB de Villiers       2
# SR Watson            2
# HH Pandya            1
# Harbhajan Singh      1
# A Nehra              1
# V Sehwag             1
# UT Yadav             1
# MS Bisla             1
# BJ Hodge             1
# MEK Hussey           1
# MS Dhoni             1
# CH Gayle             1
# MM Patel             1
# DE Bollinger         1
# AC Gilchrist         1
# RG Sharma            1
# DA Warner            1
# MC Henriques         1
# JC Buttler           1
# RM Patidar           1
# DA Miller            1
# VR Iyer              1
# SP Narine            1
# RD Gaikwad           1
# TA Boult             1
# MP Stoinis           1
# KS Williamson        1
# RR Pant              1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# ...

# %%
# sort_values
df2
df2.sort_values('ID').head(3)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 949  335982   Bangalore  2008-04-18  2007/08           1
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 947  335984       Delhi  2008-04-19  2007/08           3
#
#                            Team1                  Team2  \
# 949  Royal Challengers Bangalore  Kolkata Knight Riders
# 948              Kings XI Punjab    Chennai Super Kings
# 947             Delhi Daredevils       Rajasthan Royals
#
#                                           Venue                   TossWinner  \
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 947                            Feroz Shah Kotla             Rajasthan Royals
#
#     TossDecision SuperOver            WinningTeam    WonBy  Margin method  \
# 949        field         N  Kolkata Knight Riders     Runs   140.0    NaN
# ...

# %%
data = {
    'Name': ['Ali', 'Sara', 'Owais', 'Zara', np.nan],
    'Age': [25, 30, np.nan, 22, 28],
    'City': ['Lahore', np.nan, 'Karachi', 'Islamabad', 'Quetta']
}

x = pd.DataFrame(data)
x
# Out:
#     Name   Age       City
# 0    Ali  25.0     Lahore
# 1   Sara  30.0        NaN
# 2  Owais   NaN    Karachi
# 3   Zara  22.0  Islamabad
# 4    NaN  28.0     Quetta

# %%
# by defaulf NAN neche ata hai
x.sort_values(by='Name', na_position='last', ascending=False)
# Out:
#     Name   Age       City
# 3   Zara  22.0  Islamabad
# 1   Sara  30.0        NaN
# 2  Owais   NaN    Karachi
# 0    Ali  25.0     Lahore
# 4    NaN  28.0     Quetta

# %%
df1.head(2)
df1.sort_values(['year_of_release','title_x'], ascending = [True, False]).head(5)
# Out:
#                       title_x    imdb_id  \
# 1623                 Zubeidaa  tt0255713
# 1573      Yaadein (2001 film)  tt0248617
# 1621                  Tum Bin  tt0290326
# 1607  Nayak (2001 Hindi film)  tt0291376
# 1601         Maya (2001 film)  tt0299027
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1573  https://upload.wikimedia.org/wikipedia/en/thum...
# 1621  https://upload.wikimedia.org/wikipedia/en/thum...
# 1607  https://upload.wikimedia.org/wikipedia/en/thum...
# 1601  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1623             https://en.wikipedia.org/wiki/Zubeidaa
# 1573  https://en.wikipedia.org/wiki/Yaadein_(2001_film)
# 1621              https://en.wikipedia.org/wiki/Tum_Bin
# 1607  https://en.wikipedia.org/wiki/Nayak_(2001_Hind...
# 1601     https://en.wikipedia.org/wiki/Maya_(2001_film)
#
# ...

# %%
# rank ye sirf series me applicable hai

df = pd.read_csv('batsman_runs_ipl.csv')
df.head()
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25

# %%
df['batting_rank']=df['batsman_run'].rank(ascending= False)
df.sort_values('batting_rank')
# Out:
#            batter  batsman_run  batting_rank
# 569       V Kohli         6634           1.0
# 462      S Dhawan         6244           2.0
# 130     DA Warner         5883           3.0
# 430     RG Sharma         5881           4.0
# 493      SK Raina         5536           5.0
# ..            ...          ...           ...
# 512   SS Cottrell            0         594.0
# 466     S Kaushik            0         594.0
# 203     IC Pandey            0         594.0
# 467       S Ladda            0         594.0
# 468  S Lamichhane            0         594.0
#
# [605 rows x 3 columns]

# %%
# sort_index
df2.sort_index(ascending=False).head(3)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 949  335982   Bangalore  2008-04-18  2007/08           1
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 947  335984       Delhi  2008-04-19  2007/08           3
#
#                            Team1                  Team2  \
# 949  Royal Challengers Bangalore  Kolkata Knight Riders
# 948              Kings XI Punjab    Chennai Super Kings
# 947             Delhi Daredevils       Rajasthan Royals
#
#                                           Venue                   TossWinner  \
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 947                            Feroz Shah Kotla             Rajasthan Royals
#
#     TossDecision SuperOver            WinningTeam    WonBy  Margin method  \
# 949        field         N  Kolkata Knight Riders     Runs   140.0    NaN
# ...

# %%
# set_index
df.set_index('batter', inplace = True)

# %%
df
# Out:
#                 batsman_run  batting_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5
# ...                     ...           ...
# Yash Dayal                0         594.0
# Yashpal Singh            47         343.0
# Younis Khan               3         547.5
# Yuvraj Singh           2754          27.0
# Z Khan                  117         256.0
#
# [605 rows x 2 columns]

# %%
# reset_index
df.reset_index()
# Out:
#              batter  batsman_run  batting_rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]

# %%
df
# Out:
#                 batsman_run  batting_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5
# ...                     ...           ...
# Yash Dayal                0         594.0
# Yashpal Singh            47         343.0
# Younis Khan               3         547.5
# Yuvraj Singh           2754          27.0
# Z Khan                  117         256.0
#
# [605 rows x 2 columns]

# %%
# how to replace existing index with out lossing
df.reset_index().set_index('batting_rank')
# Out:
#                       batter  batsman_run
# batting_rank
# 166.5         A Ashish Reddy          280
# 226.0               A Badoni          161
# 535.0             A Chandila            4
# 329.0               A Chopra           53
# 402.5            A Choudhary           25
# ...                      ...          ...
# 594.0             Yash Dayal            0
# 343.0          Yashpal Singh           47
# 547.5            Younis Khan            3
# 27.0            Yuvraj Singh         2754
# 256.0                 Z Khan          117
#
# [605 rows x 2 columns]

# %%
#series to data frame using reset_index
marks = [100, 90, 86, 44]
subj = ['Maths','Physics','Chemistry','English']

s = pd.Series(marks, index = subj)
print(s)

s.reset_index()
# Out:
# Maths        100
# Physics       90
# Chemistry     86
# English       44
# dtype: int64
#        index    0
# 0      Maths  100
# 1    Physics   90
# 2  Chemistry   86
# 3    English   44

# %%
# rename column ke name change as well as index ke name change

df.rename(columns={'batsman_run':'Runs', 'batting_rank':'rank'}, inplace=True)
df.rename(index={'A Ashish Reddy':'Reddy','A Badoni':'Badoni'}, inplace= True)

# %%
df
# Out:
#                Runs   rank
# batter
# Reddy           280  166.5
# Badoni          161  226.0
# A Chandila        4  535.0
# A Chopra         53  329.0
# A Choudhary      25  402.5
# ...             ...    ...
# Yash Dayal        0  594.0
# Yashpal Singh    47  343.0
# Younis Khan       3  547.5
# Yuvraj Singh   2754   27.0
# Z Khan          117  256.0
#
# [605 rows x 2 columns]

# %%
# unique missing value bhi consider karta hai and nunique missing value count nhi karta
a = df['Runs'].nunique()
print(a)
# Out:
# 317

# %%
x
# Out:
#     Name   Age       City
# 0    Ali  25.0     Lahore
# 1   Sara  30.0        NaN
# 2  Owais   NaN    Karachi
# 3   Zara  22.0  Islamabad
# 4    NaN  28.0     Quetta

# %%
# isnull
x.isnull()
# Out:
#     Name    Age   City
# 0  False  False  False
# 1  False  False   True
# 2  False   True  False
# 3  False  False  False
# 4   True  False  False

# %%
# not null
x.notnull()
# Out:
#     Name    Age   City
# 0   True   True   True
# 1   True   True  False
# 2   True  False   True
# 3   True   True   True
# 4  False   True   True

# %%
# hasnans only working on series
x['Age'].hasnans
# Out:
# True

# %%
# dropna
x.dropna(subset=['Age','City'])
# Out:
#    Name   Age       City
# 0   Ali  25.0     Lahore
# 3  Zara  22.0  Islamabad
# 4   NaN  28.0     Quetta

# %%
x.dropna(how='all')
x.dropna(how='any')
# Out:
#    Name   Age       City
# 0   Ali  25.0     Lahore
# 3  Zara  22.0  Islamabad

# %%
# fillna
x['Age'].fillna(x['Age'].mean())
# Out:
# 0    25.00
# 1    30.00
# 2    26.25
# 3    22.00
# 4    28.00
# Name: Age, dtype: float64

# %%
x.fillna(0)
# Out:
#     Name   Age       City
# 0    Ali  25.0     Lahore
# 1   Sara  30.0          0
# 2  Owais   0.0    Karachi
# 3   Zara  22.0  Islamabad
# 4      0  28.0     Quetta

# %%
# drop duplicates
data = {
    'Name': ['Ali', 'Sara', 'Ali', 'John', 'Sara', 'Mira'],
    'Age': [25, 30, 25, 22, 30, 27],
    'City': ['Lahore', 'Karachi', 'Lahore', 'Islamabad', 'Karachi', 'Lahore']
}

f = pd.DataFrame(data)
f
# Out:
#    Name  Age       City
# 0   Ali   25     Lahore
# 1  Sara   30    Karachi
# 2   Ali   25     Lahore
# 3  John   22  Islamabad
# 4  Sara   30    Karachi
# 5  Mira   27     Lahore

# %%
f.drop_duplicates(keep ='first')
# Out:
#    Name  Age       City
# 0   Ali   25     Lahore
# 1  Sara   30    Karachi
# 3  John   22  Islamabad
# 5  Mira   27     Lahore

# %%
df2.head(3)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# ...

# %%
# find the last match played by vk in delhi

df2['all_players'] = df2['Team1Players'] + df2['Team2Players']
df2.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field  ...
#
#         WinningTeam    WonBy Margin  method Player_of_Match  \
# 0    Gujarat Titans  Wickets    7.0     NaN       HH Pandya
# 1  Rajasthan Royals  Wickets    7.0     NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
#                                         Team2Players      Umpire1  \
# ...

# %%
df2['kohli play'] = df2['all_players'].str.contains('V Kohli')
df2.head(3)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
#
#                               Venue            TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field  ...
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field  ...
#
#      WonBy Margin method  Player_of_Match  \
# 0  Wickets    7.0    NaN        HH Pandya
# 1  Wickets    7.0    NaN       JC Buttler
# 2     Runs   14.0    NaN       RM Patidar
#
# ...

# %%
df2[(df2['City'] == 'Delhi') & (df2['kohli play'] == True)].head(3).drop_duplicates(subset=['City','kohli play'], keep='first')
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision  ... WonBy Margin method  Player_of_Match  \
# 208          bat  ...  Runs   16.0    NaN         S Dhawan
#
#                                           Team1Players  \
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2                                        all_players  \
# 208  KN Ananthapadmanabhan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#     kohli play
# 208       True
#
# [1 rows x 22 columns]

# %%
f
# Out:
#    Name  Age       City
# 0   Ali   25     Lahore
# 1  Sara   30    Karachi
# 2   Ali   25     Lahore
# 3  John   22  Islamabad
# 4  Sara   30    Karachi
# 5  Mira   27     Lahore

# %%
# drop

f.drop(index = [0,1,2])
# Out:
#    Name  Age       City
# 3  John   22  Islamabad
# 4  Sara   30    Karachi
# 5  Mira   27     Lahore

# %%
f.drop(columns=['Name','Age'])
# Out:
#         City
# 0     Lahore
# 1    Karachi
# 2     Lahore
# 3  Islamabad
# 4    Karachi
# 5     Lahore

# %%
# apply

df = pd.DataFrame({
    'math': [90, 80, 70],
    'science': [85, 75, 65]
})

# sum of each row
df['total'] = df.apply(lambda row: row['math'] + row['science'], axis=1)

print(df)
# Out:
#    math  science  total
# 0    90       85    175
# 1    80       75    155
# 2    70       65    135
